# %% [markdown]
# <div style='background-image: url("images/mushroom_classification.jpg"); height:780px;'>
#     <h1 style='color: white; padding: 10px;'><b>Mushroom Classification</b></h1>
# <p style='text-align: justify;'>
#   <h3 style='color: white; padding: 10px;'>Context:</h3>
#     <p style='color: white; padding: 10px;'>Although this dataset was originally contributed to the UCI Machine Learning repository nearly 30 years ago, mushroom hunting (otherwise known as "shrooming") is enjoying new peaks in popularity. Learn which features spell certain death and which are most palatable in this dataset of mushroom characteristics. And how certain can your model be?</p>
#     <h3 style='color: white; padding: 10px;'>Content:</h3>
#     <p style='color: white; padding: 10px;'>This dataset includes descriptions of hypothetical samples corresponding to 23 species of gilled mushrooms in the Agaricus and Lepiota Family Mushroom drawn from The Audubon Society Field Guide to North American Mushrooms (1981). Each species is identified as definitely edible, definitely poisonous, or of unknown edibility and not recommended. This latter class was combined with the poisonous one. The Guide clearly states that there is no simple rule for determining the edibility of a mushroom; no rule like "leaflets three, let it be'' for Poisonous Oak and Ivy.</p>
#     <ul style='color: white; padding: 25px;'>
#       <li><b>Time period</b>: Donated to UCI ML 27 April 1987</li>
#     </ul>
#     <h3 style='color: white; padding: 10px;'>Inspiration</h3>
#     <ul style='color: white; padding: 25px;'>
#       <li>What types of machine learning models perform best on this dataset?</li>
#       <li>Which features are most indicative of a poisonous mushroom?</li>
#     </ul>
#     <div style='background-color: gray; padding: 3px;'>
#     <h3 style='color: white; padding: 10px;'>Acknowledgements</h3>
#     <p style='color: white; padding: 10px;'>This dataset was originally donated to the UCI Machine Learning repository. You can learn more about past research using the data <a style='color: white; padding: 10px;' href='"https://archive.ics.uci.edu/ml/datasets/Mushroom'>here</a>.</p>
#         <b style='color: white; padding: 10px;'>This introductory information of this dataset and more  kernels can be found at <a style='color: white; padding: 10px;' href='https://www.kaggle.com/uciml/mushroom-classification'>kaggle</a></b>.
# </p>
#     </div>
# </div>

# %% [markdown]
# <h1>Machine Learning Workflow</h1>
# <p style='text-align: justify;'>
#   The workflow that is going to be implemented is based on current enterprise standards, in fact this workflow is explained, implemented and taught by Google, this can be checked in this post <a href='https://towardsdatascience.com/the-7-steps-of-machine-learning-2877d7e5548e'>The 7 Steps of Machine Learning</a>  or can be watch <a href='https://youtu.be/nKW8Ndu7Mjw?list=PLIivdWyY5sqJxnwJhe3etaK7utrBiPBQ2'>here</a>.
# <p>
# <h2>Workflow:</h2>
# <p>
#   <ul>
#     <li>Gathering Data.</li>
#     <li>Data Preparation.</li>
#     <li>Choosing a Model.</li>
#     <li>Training.</li>
#     <li>Evaluation</li>
#     <li>Parameter Tuning.</li>
#     <li>Prediction</li>
#    </ul>
# </p>
# <p>
#   This <b>Workflow</b> is usually compose of inner steps in each of its phases, every of this phases are optional, they depend of the results of previous phases or steps.
# </p>

# %% [markdown]
# <h2>Gathering Data</h2>
# <p>In this case we already have a way to obtained the dataset to work on, which can be found <a href='https://www.kaggle.com/uciml/mushroom-classification'>here</a>.
#   <br><br>
#   <b>Gathering Data</b> is just the requiered process to obtained the dataset, in certain scenarios implementation of queries to data bases is requierd to obtained a dataset or even generation of data through polls. This project is being develop using Google Colaboratory, to start using our Mushroom Classification dataset, the cell below must be run and its instructions must be followed.
# </p>

# %%
from google.colab import files
dataset_file_dict = files.upload()

# %% [markdown]
# The next libraries are very popular for data handling, the  library <code>pandas</code> will allow proper data handling for import our dataset into memory.<br>

# %%
import pandas as pd
data = pd.read_csv('mushrooms.csv')

# %% [markdown]
# The <b>Gathering Data</b> phase has been completed, the next phase is <b>Data Preparation</b>.<br>
# <h2>Data Preparation</h2>
# <p>
#   <i>How can we prepare something that is unknown?</i> The phase of <b>Data Preparation</b> involves getting to know the dataset, for that an <b>Exploratory Data Analysis</b> must be applied, more information of what <a href='https://en.wikipedia.org/wiki/Exploratory_data_analysis'><b>EDA</b></a> is.
# </p>

# %% [markdown]
# The function <code>shape</code> gives us how many rows and columns the dataset is composed.
# <ul>
#   <li>Rows: 8124</li>
#   <li>Columns: 23</li>
# </ul>

# %%
data.shape
# Out:
# (8124, 23)

# %% [markdown]
# The dataset has <i>8124 observations and 23 features</i>. But <b>how many predictors?</b><br>
# Functions such as <code>head()</code> or <code>tail()</code> display the <b>n</b> "headers" and "tailers" rows of the dataset, in this case the <code>sample()</code> function display random rows.

# %%
data.sample(10)
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 2447     e         f           f         n       t    n               f
# 66       e         x           s         w       t    l               f
# 7216     p         k           y         n       f    s               f
# 1318     e         b           s         y       t    l               f
# 4429     p         x           y         n       f    y               f
# 6434     e         x           s         n       f    n               a
# 5182     p         f           y         y       f    f               f
# 6533     p         x           y         e       f    f               f
# 1788     e         x           s         g       f    n               f
# 4656     p         f           f         y       f    f               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 2447            c         b          p  ...                        s
# ...

# %% [markdown]
# It is displayed that the dataset is formed by 22 predictors/features and one class, which is the dependent variable that it is intent to predict.<br>

# %% [markdown]
# <p>Let's check for the data type of every feature present in the dataset.</p>

# %%
# See the column data types and non-missing values
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
# class                       8124 non-null object
# cap-shape                   8124 non-null object
# cap-surface                 8124 non-null object
# cap-color                   8124 non-null object
# bruises                     8124 non-null object
# odor                        8124 non-null object
# gill-attachment             8124 non-null object
# gill-spacing                8124 non-null object
# gill-size                   8124 non-null object
# gill-color                  8124 non-null object
# stalk-shape                 8124 non-null object
# stalk-root                  8124 non-null object
# stalk-surface-above-ring    8124 non-null object
# stalk-surface-below-ring    8124 non-null object
# stalk-color-above-ring      8124 non-null object
# stalk-color-below-ring      8124 non-null object
# veil-type                   8124 non-null object
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# <p>Looking for the kind of categorical feature that the depend variable holds, it is an essential step to know, what values are those that must be predicted.</p>

# %%
data['class'].unique()
# Out:
# array(['p', 'e'], dtype=object)

# %% [markdown]
# <p><b>p</b> and <b>e</b> are the values that the model that must be build will have to predict.<br>
# <p>Because of only having two values that can be predicted, the model that is going to be build will rely on binary categorical predictions.
# <p>The next computation will intend to give how many of these values are presented.</p>

# %%
data['class'].value_counts()
# Out:
# e    4208
# p    3916
# Name: class, dtype: int64

# %% [markdown]
# <p>This dataset is composed by a total of <b>8124</b> predictions, formed by <b>4208</b> as <b>e</b> and <b>3916</b> as <b>p</b>, by simple sight it is seem that these dataset is not skewed.<br>
# Inspect every feature, brings a better understanding of how the dependent feature works and ofcourse how predictions will work, for this task, the code below will display every value that it is found in every feature.
# </p>

# %%
for columnName in data.columns:
  values = data[columnName].unique()
  print('{quantity} values in column {columnName}:'.format(quantity=values.size,columnName=columnName))
  print('\t{values}'.format(values=values))
# Out:
# 2 values in column class:
# 	['p' 'e']
# 6 values in column cap-shape:
# 	['x' 'b' 's' 'f' 'k' 'c']
# 4 values in column cap-surface:
# 	['s' 'y' 'f' 'g']
# 10 values in column cap-color:
# 	['n' 'y' 'w' 'g' 'e' 'p' 'b' 'u' 'c' 'r']
# 2 values in column bruises:
# 	['t' 'f']
# 9 values in column odor:
# 	['p' 'a' 'l' 'n' 'f' 'c' 'y' 's' 'm']
# 2 values in column gill-attachment:
# 	['f' 'a']
# 2 values in column gill-spacing:
# 	['c' 'w']
# 2 values in column gill-size:
# 	['n' 'b']
# 12 values in column gill-color:
# 	['k' 'n' 'g' 'p' 'w' 'h' 'u' 'e' 'b' 'r' 'y' 'o']
# 2 values in column stalk-shape:
# 	['e' 't']
# 5 values in column stalk-root:
# 	['e' 'c' 'b' 'r' '?']
# 4 values in column stalk-surface-above-ring:
# 	['s' 'f' 'k' 'y']
# 4 values in column stalk-surface-below-ring:
# 	['s' 'f' 'y' 'k']
# 9 values in column stalk-color-above-ring:
# 	['w' 'g' 'p' 'n' 'b' 'e' 'o' 'c' 'y']
# 9 values in column stalk-color-below-ring:
# 	['w' 'p' 'g' 'b' 'n' 'e' 'y' 'o' 'c']
# ...

# %% [markdown]
# <p>The feature <b>veil-type</b> it only holds one unique value, the value of <b>p</b>, by simple logic it is concluded that the veil-type of a mushroom does not contribute to know whether the mushroom is edible or poisonous, therefore this feature can be dropped from the feature space.<br>
#     Adding, removing feature from a dataset it is called <b>Feature Engineering</b>, this will be applied later.</p>

# %%
data = data.drop(['veil-type'],axis=1)

# %% [markdown]
# <p>With the removal of the feature veil-type, it is good to know how many features the dataset is made of.</p>

# %%
data.dtypes.value_counts()
# Out:
# object    22
# dtype: int64

# %% [markdown]
# <p>A good practice is to search for null values, a null value can create conflict on the computation of the model and even affect positively or negatively the results of the model.

# %%
data.isnull().values.any()
# Out:
# False

# %% [markdown]
# <p>The dataset does not have any single null value.<br>
# <h3>Plotting</h3><br>
# <b>Frequency Distribution</b> is an overview of all distinct values in some variable and the number of times they occur, this kind of plots allow to know if there is a class imbalance problem. As is shown there is not a higher dominance in the dataset for one class over the other class.
# <a href='https://www.statisticshowto.datasciencecentral.com/probability-and-statistics/skewed-distribution/'>For a better understanding of imbalance dataset & skewed dataset</a>.
# </p>

# %%
sns.countplot(x='class', data=data);

# %% [markdown]
# <div>
#     <p style='text-align: justify;'>
#         <b>Allocating feautures and Label</b>: In the next two below cells, the code will execute the allocation of the <i>label</i> in the array <b>y</b> and the feature space in the matrix <b>X</b>.
#     </p>
# </div>

# %% [markdown]
# <div>
# </div>

# %%
# Select target
y = data['class']
y.shape
# Out:
# (8124,)

# %%
y = y.values

# %%
# Select features, with no feature selection or feature importance
X = data.drop(['class'], axis=1)
X.shape
# Out:
# (8124, 21)

# %%
X = X.values

# %% [markdown]
# <h3>Feature Importance</h3>
# <p style='text-align: justify;'>
#     The problem that is being faced with this dataset, is that every feature is categorical and one of the most popular ways to define <b>feature importance</b> is based on the <i>correlation</i> of the feature with the label (value to predict) of the dataset and correlation is defined by numerical features <i>if there is a linear relationship and symmetry with the predicted value. </i><a href='https://en.wikipedia.org/wiki/Correlation_and_dependence'>This is explained here</a> and
#     <a href='https://towardsdatascience.com/the-search-for-categorical-correlation-a1cf7f1888c9'>The best answer to this situation can be found here</a>.<br><br>
#     <a href='https://en.wikipedia.org/wiki/Uncertainty_coefficient'><b>Theil’s U</b></a> is based on the conditional entropy between x and y — or in human language, given the value of x, how many possible states does y have, and how often do they occur. The output value is on the range of [0,1], it is asymmetric, meaning U(x,y)≠U(y,x) (while V(x,y)=V(y,x), where V is Cramer’s V). Using Theil’s U in the simple case above will let us find out that knowing y means we know x, but not vice-versa.<br>
#     <ul>
#         <li><a href='https://math.stackexchange.com/questions/770709/understanding-conditional-entropy-intuitively-hyx-x-vs-hyx'>Understanding Conditional Entropy Intuitively</a></li>
#     </ul>
# </p>

# %%
#@title
# Feature importances and correlations 
import math
from collections import Counter
import numpy as np
import seaborn as sns
import pandas as pd
import scipy.stats as ss
import matplotlib.pyplot as plt
import sklearn.preprocessing as sp
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from subprocess import check_output

def conditional_entropy(x,y):
  # entropy of x given y
  y_counter = Counter(y)
  xy_counter = Counter(list(zip(x,y)))
  total_occurrences = sum(y_counter.values())
  entropy = 0
  for xy in xy_counter.keys():
    p_xy = xy_counter[xy] / total_occurrences
    p_y = y_counter[xy[1]] / total_occurrences
    entropy += p_xy * math.log(p_y/p_xy)
  return entropy

def theils_u(x, y):
  s_xy = conditional_entropy(x,y)
  x_counter = Counter(x)
  total_occurrences = sum(x_counter.values())
  p_x = list(map(lambda n: n/total_occurrences, x_counter.values()))
  s_x = ss.entropy(p_x)
  if s_x == 0:
      return 1
  else:
      return (s_x - s_xy) / s_x

# %% [markdown]
# <p style='text-align: justify;'>
#     Once that the concepts of <b>Theil's U</b> and <b>Conditional Entropy</b> are understood, it is time to plot how related are the features to the label. This will be shown by the code below this cell.
# </p>

# %%
#@title

theilu = pd.DataFrame(index=['class'],columns=data.columns)
columns = data.columns
for j in range(0,len(columns)):
  u = theils_u(data['class'].tolist(),data[columns[j]].tolist())
  theilu.loc[:,columns[j]] = u
theilu.fillna(value=np.nan,inplace=True)
plt.figure(figsize=(20,1))
sns.heatmap(theilu, annot=True, fmt='.2f')
plt.show()

# %% [markdown]
# <p style='text-align: justify;'>
#     Now that is known how much every feature contributes to the label, it is time to know how much associated are every feature with each other, including the label with each feature.
# </p>

# %%
#@title
def convert(data, to):
    converted = None
    if to == 'array':
        if isinstance(data, np.ndarray):
            converted = data
        elif isinstance(data, pd.Series):
            converted = data.values
        elif isinstance(data, list):
            converted = np.array(data)
        elif isinstance(data, pd.DataFrame):
            converted = data.as_matrix()
    elif to == 'list':
        if isinstance(data, list):
            converted = data
        elif isinstance(data, pd.Series):
            converted = data.values.tolist()
        elif isinstance(data, np.ndarray):
            converted = data.tolist()
    elif to == 'dataframe':
        if isinstance(data, pd.DataFrame):
            converted = data
        elif isinstance(data, np.ndarray):
            converted = pd.DataFrame(data)
    else:
        raise ValueError("Unknown data conversion: {}".format(to))
    if converted is None:
        raise TypeError('cannot handle data conversion of type: {} to {}'.format(type(data),to))
    else:
      return converted

def associations(dataset, nominal_columns=None, mark_columns=False, theil_u=False, plot=True,
                          return_results = False, **kwargs):
    """
    Calculate the correlation/strength-of-association of features in data-set with both categorical (eda_tools) and
    continuous features using:
     - Pearson's R for continuous-continuous cases
     - Correlation Ratio for categorical-continuous cases
     - Cramer's V or Theil's U for categorical-categorical cases
    :param dataset: NumPy ndarray / Pandas DataFrame
        The data-set for which the features' correlation is computed
    :param nominal_columns: string / list / NumPy ndarray
        Names of columns of the data-set which hold categorical values. Can also be the string 'all' to state that all
        columns are categorical, or None (default) to state none are categorical
    :param mark_columns: Boolean (default: False)
        if True, output's columns' names will have a suffix of '(nom)' or '(con)' based on there type (eda_tools or
        continuous), as provided by nominal_columns
    :param theil_u: Boolean (default: False)
        In the case of categorical-categorical feaures, use Theil's U instead of Cramer's V
    :param plot: Boolean (default: True)
        If True, plot a heat-map of the correlation matrix
    :param return_results: Boolean (default: False)
        If True, the function will return a Pandas DataFrame of the computed associations
    :param kwargs:
        Arguments to be passed to used function and methods
    :return: Pandas DataFrame
        A DataFrame of the correlation/strength-of-association between all features
    """

    dataset = convert(dataset, 'dataframe')
    columns = dataset.columns
    if nominal_columns is None:
        nominal_columns = list()
    elif nominal_columns == 'all':
        nominal_columns = columns
    corr = pd.DataFrame(index=columns, columns=columns)
    for i in range(0,len(columns)):
        for j in range(i,len(columns)):
            if i == j:
                corr[columns[i]][columns[j]] = 1.0
            else:
                if columns[i] in nominal_columns:
                    if columns[j] in nominal_columns:
                        if theil_u:
                            corr[columns[j]][columns[i]] = theils_u(dataset[columns[i]],dataset[columns[j]])
                            corr[columns[i]][columns[j]] = theils_u(dataset[columns[j]],dataset[columns[i]])
                        else:
                            cell = cramers_v(dataset[columns[i]],dataset[columns[j]])
                            corr[columns[i]][columns[j]] = cell
                            corr[columns[j]][columns[i]] = cell
                    else:
                        cell = correlation_ratio(dataset[columns[i]], dataset[columns[j]])
                        corr[columns[i]][columns[j]] = cell
                        corr[columns[j]][columns[i]] = cell
                else:
                    if columns[j] in nominal_columns:
                        cell = correlation_ratio(dataset[columns[j]], dataset[columns[i]])
                        corr[columns[i]][columns[j]] = cell
                        corr[columns[j]][columns[i]] = cell
                    else:
                        cell, _ = ss.pearsonr(dataset[columns[i]], dataset[columns[j]])
                        corr[columns[i]][columns[j]] = cell
                        corr[columns[j]][columns[i]] = cell
    corr.fillna(value=np.nan, inplace=True)
    if mark_columns:
        marked_columns = ['{} (nom)'.format(col) if col in nominal_columns else '{} (con)'.format(col) for col in columns]
        corr.columns = marked_columns
        corr.index = marked_columns
    if plot:
        plt.figure(figsize=kwargs.get('figsize',None))
        sns.heatmap(corr, annot=kwargs.get('annot',True), fmt=kwargs.get('fmt','.2f'))
        plt.show()
    if return_results:
      return corr

# %%
#@title
associations = associations(data, 'all', theil_u=True, plot=False, return_results=True)

# %%
#@title
plt.figure(figsize = (20,10))
sns.heatmap(associations, annot=True, fmt='.2f')
plt.show()

# %% [markdown]
# <p style='text-align: justify;'>
#     <h3>Feature Selection</h3>
#     <br>
#     The association are known and it is time to choose the features with the biggest contributions. For this a threshold must be set up intuitively, only those features that accomplish the conditions will be the ones that are going to be used to trained and test the model. By trial and error is how this features will be chosen.
#     <br>
# </p>

# %%
stronger_associations_ = associations.loc['class',:]
stronger_associations_ = stronger_associations_.sort_values(ascending=False)
stronger_associations_ = stronger_associations_[stronger_associations_>0.27]
stronger_associations_
# Out:
# class                       1.000000
# odor                        0.906920
# spore-print-color           0.481153
# gill-color                  0.417367
# ring-type                   0.318318
# stalk-surface-above-ring    0.284991
# stalk-surface-below-ring    0.272148
# Name: class, dtype: float64

# %% [markdown]
# <p style='text-align: justify;'>
#     At the begining the dataset was composed by 22 features thanks to Theil's U function and the threshold set, our dataset was reduced to only 6 features. Lets create a new variables, X_strong_assoc is going to hold the 6 principal features.
# </p>

# %%
X_strong_assoc = data[{'odor', 'spore-print-color', 'gill-color', 'ring-type', 'stalk-surface-above-ring', 'stalk-surface-below-ring'}]
X_strong_assoc = X_strong_assoc.values
X_strong_assoc
# Out:
# array([['s', 's', 'p', 'k', 'k', 'p'],
#        ['s', 's', 'a', 'n', 'k', 'p'],
#        ['s', 's', 'l', 'n', 'n', 'p'],
#        ...,
#        ['s', 's', 'n', 'b', 'n', 'p'],
#        ['k', 's', 'y', 'w', 'b', 'e'],
#        ['s', 's', 'n', 'o', 'y', 'p']], dtype=object)

# %% [markdown]
# <p style='text-align: justify;'>
# <h3>Single Feature Exploration</h3>
#      <p style='text-align: justify;'>
#         For what is known the feature <b>Odor</b> has the strongest association with the label, this is the feature that is prefered to be explored.
#         There are 9 types of odor, every single of these types is associated with corresponding to an edible or
#     poisonous mushroom, what is going to be done as exploration is to know how many mushrooms are by type of odor.
#      </p>
# </p>

# %%
#@title
sns.set(rc={'figure.figsize':(15,8)})
ax=sns.countplot(x='odor',hue='class',data=data)
for p in ax.patches:
    patch_height = p.get_height()
    if np.isnan(patch_height):
        patch_height = 0
    ax.annotate('{}'.format(int(patch_height)), (p.get_x()+0.05, patch_height+10))
plt.show()

# %% [markdown]
# <p style='text-align: justify;'>
#     The exploration of the single feature is done, and it is concluded that there are types of odor that are only associated with one kind of label.
# </p>

# %% [markdown]
# <p>
#     The dataset is going to be randomly splited into training and test sets.
#     <ul>
#         <li><b>Training Set</b>:</li>
#         <ul>
#             <li><b>X_train</b>: This set is formed by 70% of the total feature examples presented in the dataset, <i>it does not include the label.</i></li>
#             <li><b>y_train</b>: This set is formed by 70% of the total label examples presented in the dataset, <i>it does not include the features.</i></li>
#         </ul>
#         <li><b>Test Set</b>:</li>
#         <ul>
#             <li><b>X_test</b>: This set is formed by 30% of the total feature examples presented in the dataset, <i>it does not include the label.</i></li>
#             <li><b>y_test</b>:This set is formed by 30% of the total label examples presented in the dataset, <i>it does not include the features.</i></li>
#         </ul>
#     </ul>
#    <b>Note</b>: These sets of training and testing are not going to be used for model selection, instead these set will be used to <b>check for linearity</b> in the dataset, this check is done with the whole dataset.
# </p>

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, roc_auc_score, recall_score, r2_score, accuracy_score, precision_recall_curve, precision_recall_fscore_support, precision_score


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %% [markdown]
# <p style='text-align: justify'>
#     scikit learn library does not support character processing, therefore the values presented in the dataset must be encoded.
#     <ul>
#         <li>Features will be One Hot Encoded. <a href='https://towardsdatascience.com/encoding-categorical-features-21a2651a065c'>What is OneHotEncoding?</a></li>
#         <li>Labels will be binarized. <a href='https://www.datacamp.com/community/tutorials/categorical-data'>What is LabelBinarizer?</a></li>
#     </ul>
# </p>

# %%
from sklearn.preprocessing import OneHotEncoder
ohc = OneHotEncoder()
X = ohc.fit_transform(X)
X_train = ohc.fit_transform(X_train)
X_test = ohc.fit_transform(X_test)

# %%
from sklearn.preprocessing import LabelBinarizer
y = LabelBinarizer().fit_transform(y)
y_train = LabelBinarizer().fit_transform(y_train)
y_test = LabelBinarizer().fit_transform(y_test)

# %%
X_strong_train, X_strong_test = train_test_split(X_strong_assoc, test_size=0.30, random_state=42)
X_strong_assoc = ohc.fit_transform(X_strong_assoc)
X_strong_train = ohc.fit_transform(X_strong_train)
X_strong_test = ohc.fit_transform(X_strong_test)

# %% [markdown]
# <h1>Model Selection</h1>
# <h3>Check for Linearity</h3>
# <p style='text-align: justify;'>
#     It is essential to check for linearity in the dataset, this will help in determined what kind of algorithms to use.<br>
# </p>

# %% [markdown]
# <p style='text-align: justify;'>
# To discover if the dataset corresponds to linearity it helps to use <a href='https://scikit-learn.org/stable/modules/svm.html'><b>Support Vector Machines</b></a>, according to scikit-learng documentation, this is how <b>SVC</b> helps:
#     <ul>
#         <li>Advantages:</li>
#         <ul>
#             <li>Effective in high dimensional spaces.</li>
#             <li>Still effective in cases where number of dimensions is greater than the number of samples.</li>
#             <li>Uses a subset of training points in the decision function (called support vectors), so it is also memory efficient.</li>
#             <li>Versatile: different <b>Kernel functions</b> can be specified for the decision function. Common kernels are provided, but it is also possible to specify custom kernels.</li>
#         </ul>
#         <li>Disadvantages:</li>
#         <ul>
#             <li>If the number of features is much greater than the number of samples, avoid over-fitting in choosing <a href='https://scikit-learn.org/stable/modules/svm.html#svm-kernels'><b>Kernel functions</b></a> and regularization term is crucial.</li>
#             <li>SVMs do not directly provide probability estimates, these are calculated using an expensive five-fold cross-validation.</li>
#         </ul>
#     </ul>
#     <a href='http://langvillea.people.cofc.edu/DISSECTION-LAB/Emmie%27sLSI-SVDModule/p5module.html'>Truncated SVD</a> (<a href='https://en.wikipedia.org/wiki/Singular_value_decomposition'>Singular Value Decomposition</a>) it is used to find a reduced rank approximation to a matrix by setting all but the first k largest singular values equal to zero and using only the first k columns of de matrix decomposition.
# </p>

# %%
from sklearn.svm import SVC, LinearSVC
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.decomposition import TruncatedSVD

def get_truncatedSVD(X):
  t_svd = TruncatedSVD(n_components=2,random_state=42)
  t_svd = t_svd.fit_transform(X)
  return t_svd

def make_meshgrid(x, y, h=.02):
    x_min, x_max = x.min() - 1, x.max() + 1
    y_min, y_max = y.min() - 1, y.max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    return xx, yy

names = ['Linear SVM', 'RBF SVM', 'Poly SVM', 'Sigmoid SVM']
classifiers = [
    SVC(kernel='linear', C=1),
    SVC(gamma=1, C=1),
    SVC(kernel='poly', C=1),
    SVC(kernel='sigmoid', gamma=1)]

figure = plt.figure(figsize=(12,3))
h = .02 # Step size in the mesh
i = 1

Xreduced = get_truncatedSVD(X)
X0, X1 = Xreduced[:, 0], Xreduced[:, 1]
xx_test, xx_train, yy_test, yy_train = train_test_split(Xreduced, y, test_size=0.3, random_state=42)
xx, yy = make_meshgrid(X0, X1)

# Just plot the dataste first
cm = plt.cm.RdBu
cm_bright = ListedColormap(['#FF0000', '#0000FF'])
ax = plt.subplot(1, len(classifiers) + 1, i)

# Plot the training points
ax.scatter(xx_train[:, 0], xx_train[:, 1], c=yy_train.ravel(), cmap=cm_bright)
# And testing points
ax.scatter(xx_test[:, 0], xx_test[:, 1], c=yy_test.ravel(), cmap=cm_bright, alpha=0.6)


# fig, ax = plt.subplots()
# title for the plots
# title = ('Decision surface of linear SVC ')
# Set-up grid for plotting.
X0, X1 = Xreduced[:, 0], Xreduced[:, 1]
xx, yy = make_meshgrid(X0, X1)
ax.set_xlim(xx.min(), xx.max())
ax.set_ylim(yy.min(), yy.max())
ax.set_xticks(())
ax.set_yticks(())
ax.set_title('TruncatedSVD')

i += 1

# Iterate over classifiers
for name, clf in zip(names, classifiers):
  ax = plt.subplot(1, len(classifiers) + 1, i)
  clf.fit(xx_train, yy_train)
  score = clf.score(xx_test, yy_test)
  
  # Plor the decission boundary. For that, we will assign a color to each poiny in the mesh [x_min, m_max]x[y_min, y_max]
  if hasattr(clf, "decision_function"):
    Z = clf.decision_function(np.c_[xx.ravel(), yy.ravel()])
  else:
    Z = clf.predict_proba(np.c_[xx.ravel(), yy.ravel()])[:, 1]
  
  # Put the result into a color plot
  Z = Z.reshape(xx.shape)
  ax.contourf(xx, yy, Z, cmap=cm, alpha=.8)
  
  # Plot also the training points
  ax.scatter(xx_train[:, 0], xx_train[:, 1], c=yy_train.ravel(), cmap=cm_bright)
  # And testing points
  ax.scatter(xx_test[:, 0], xx_test[:, 1], c=yy_test.ravel(), cmap=cm_bright, alpha=.06)
  
  ax.set_xlim(xx.min(), xx.max())
  ax.set_ylim(yy.min(), yy.max())
  ax.set_xticks(())
  ax.set_yticks(())
  ax.set_title(name)
  ax.text(xx.max() - .3, yy.min() + .3, ('%.2f' % score).lstrip('0'), size=15, horizontalalignment='right')
  
  i += 1

figure.subplots_adjust(left=.02, right=.98)
plt.show()
# Out:
# C:\Users\kleye\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\kleye\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\kleye\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %% [markdown]
# <p style='text-align: justify;'>
# The results have been obtained and the features do not have a linear relationship with the label, instead the relationship presented is <a href='https://towardsdatascience.com/radial-basis-functions-neural-networks-all-we-need-to-know-9a88cc053448'>Radial Basis Function (RBF)</a>. This means that the algorithm to use must use a RBF as kernel. <br>
# <a href='https://www.youtube.com/watch?v=Z2_yh2sice8'>This video provides an explanation of RBF.</a>
# </p>

# %% [markdown]
# <p style='text-align: justify;'>
#     <h3>What algorithm to use?</h3>
#     <br>
#     It is recommended to use scikit learn <a href='https://scikit-learn.org/stable/tutorial/machine_learning_map/index.html'>flow chart</a> of model selection.
#      <img src="images/ScikitLearnFlowChart.png" alt="Model/Estimator Flow Chart" width="600" height="700"><br>
#      According to that flow chart and to what is known of the dataset:
#      <ul>
#         <li>Dataset is composed by 8124 sambles.</li>
#         <li>Is required to predict a category.</li>
#         <li>The data presented is labeled.</li>
#         <li>Dataset is composed by less than 100k samples.</li>
#         <li>Features in the dataset do not have a linear relationship.</li>
#     <li>The data in the dataset is text data. <b>Naive Bayes</b> is a candidate but when OneHotEncoding and LabelBinarizer were applied, the data became numerical, therefore more algorithms could be candidates.</li>
#     <li><b>KNeighbors Classifier</b> and <b>SVC</b> are the last candidates to consider.</li>
#      </ul>
#      <br>
#      The algorithms to evaluate will be:
#      <ul>
#         <li>Naive Bayes with <a href='https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html'>MultinomialNB.</a></li>
#         <li>KNeighbors Classifier.</li>
#         <li>SVC with RBF as kernel.</li>
#      </ul>
#      Every single model will be evaluated by ROC-AUC, accuracy score and time execution.
#      This can be explained here:
#      <ul>
#          <li><a href='https://machinelearningmastery.com/roc-curves-and-precision-recall-curves-for-classification-in-python/'>How and When to Use ROC Curves and Precision-Recall Curves for Classification in Python</a></li>
#         <li><a href='https://medium.com/swlh/recall-precision-f1-roc-auc-and-everything-542aedf322b9'>Recall, Precision, F1, ROC, AUC, and everything</a></li>
#         <li><a href='https://towardsdatascience.com/understanding-auc-roc-curve-68b2303cc9c5'>Understanding AUC - ROC Curve</a></li>
#      </ul>
# </p>

# %%
import time
def time_consumption(time_start, time_end):
    return time_end - time_start

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
names = ['Naive Bayes MultinomialNB', 'KNeighbors Classifier', 'SVC RBF']
models =[MultinomialNB(), KNeighborsClassifier(n_neighbors=3, algorithm='auto'), SVC(kernel='rbf', gamma=1, C=1, probability=True)] 
score = []
elapsed_time = []

for name, model in zip(names, models):
    time_start = time.time()
    model.fit(X_strong_train, y_train)
    model_predict = model.predict(X_strong_test)
    time_end = time.time()
    elapsed_time.append(time_consumption(time_start, time_end))
    probs = model.predict_proba(X_strong_test)
    probs = probs[:, 1]
    score.append(accuracy_score(y_test, model_predict))
    # Compute False postive rate, and True positive rate
    fpr, tpr, thresholds = roc_curve(y_test, probs)
    # Calculate Area under the curve to display on the plot
    auc = roc_auc_score(y_test, model_predict)
    # Now, plot the computed values
    plt.plot(fpr, tpr, label='%s ROC (area = %0.2f)' % (name, auc), visible=True)
plt.plot([0, 1], [0, 1],'--')
plt.xlabel('Specificity(False Positive Rate)')
plt.ylabel('Sensitivity(True Positive Rate)')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# C:\Users\kleye\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\kleye\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   if sys.path[0] == '':
# C:\Users\kleye\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from IPython.core.pylabtools import figsize
plt.style.use('fivethirtyeight')
figsize(8, 6)
model_comparison = pd.DataFrame({'model': names, 'score': score})
model_comparison.sort_values('score', ascending=False).plot(x = 'model', y = 'score', kind = 'barh',
                                                            color = 'lightblue', edgecolor = 'black')
plt.ylabel(''); plt.yticks(size = 14); plt.xlabel('Accuracy Score'); plt.xticks(size = 14)
plt.title('Model Comparison on Test Accuracy Score', size = 20);

# %%
#elapsed_time
time_comparison = pd.DataFrame({'model': names, 'Time': elapsed_time})
time_comparison = time_comparison.sort_values('Time', ascending=True)
#.plot(x = 'model', y = 'time', kind='bar', color = 'lightblue', edgecolor = 'black')

#sns.set(rc={'figure.figsize':(15,8)})
ax=sns.barplot(x=time_comparison.model,y = time_comparison.Time, hue=time_comparison.Time, data=time_comparison)
plt.xlabel('Model Name', size=15)
plt.ylabel('Time Execution (s)', size=15)
plt.title('Model and Time Execution', size=20)
plt.show()

# %% [markdown]
# <p style='text-align: justify;'>
#     The best model is <b>SVC</b> because its perfect score on ROC and AUC test, is less time comsuming than KNeighbors Classifier.<br>
#     Creating a new model, training it to finally make predictions.
# </p>

# %%
from sklearn.metrics import confusion_matrix

model = SVC(kernel='rbf', gamma=1, C=1)
model.fit(X_strong_train, y_train)
model_predict = model.predict(X_strong_test)
# Out:
# C:\Users\kleye\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([[1257,    0],
#        [   3, 1178]], dtype=int64)

# %% [markdown]
# <p>
#     The <b>SVC</b> model and its accuracy:
# </p>

# %%
accuracy_score(y_test, model_predict)
# Out:
# 0.9987694831829368

# %% [markdown]
# <p style='text-align: justify;'>
# Plotting a <a href='https://en.wikipedia.org/wiki/Confusion_matrix'>confusion matrix</a> to have a visual representation of how well and bad the model performed, is what is going be done.
# <img src='images/confusion_matrix.png' style='float:left'>
# </p>

# %%
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(y_test_, model_predict_, classes, normalize=False, title=None, cmap=plt.cm.Blues):
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'
            
    cm = confusion_matrix(y_test, model_predict)
    if normalize:
        cm = cm.astype('float')/cm.sum(axis=1)[:, np.newaxis]       
    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]),
               yticks=np.arange(cm.shape[0]),
               # ... and label them with the respective list entries
               xticklabels=['p', 'e'], yticklabels=['p', 'e'],
               title=title,
               ylabel='True label',
               xlabel='Predicted label')
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plot_confusion_matrix(y_test,  model_predict, classes=['p', 'e'],
                      title='Confusion matrix, without normalization')

# Plot normalized confusion matrix
plot_confusion_matrix(y_test, model_predict, classes=['p', 'e'], normalize=True,
                      title='Normalized confusion matrix')

plt.show()

# %% [markdown]
# <p style='text-align: justify;'>
#     <h3>SVC Model Performance's Overview</h3>
#     <br>
#     The model behaves perfect when it predicts edible mushrooms but it fails by less than 0.002% predicting poisonous mushrooms.<br>
#
# </p>
